# %% [markdown]
# <a href="https://colab.research.google.com/github/zulqurnain233/Github-Test/blob/main/session4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
number = 7
for i in range(1,11):
  result = number *i
  print(f"{number} * 1 = {result}")
# Out:
# 7 * 1 = 7
# 7 * 1 = 14
# 7 * 1 = 21
# 7 * 1 = 28
# 7 * 1 = 35
# 7 * 1 = 42
# 7 * 1 = 49
# 7 * 1 = 56
# 7 * 1 = 63
# 7 * 1 = 70

# %%
#print numbers from 100 to 120 using for loop.
for i in range(120,99,-1):
  print(i,end=" ")
# Out:
# 120 119 118 117 116 115 114 113 112 111 110 109 108 107 106 105 104 103 102 101 100
